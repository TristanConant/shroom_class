# %% [markdown]
# <a href="https://colab.research.google.com/github/TristanConant/shroom_class/blob/main/Copy_of_project_2_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

# %%
file_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQ94PFNlOYMndbOU8lOH9YTaPKyngt0V2KDC47hQnGm9fvdbtXa3OXhu3AKnDzzBYEQlSw2UxS7Q7XI/pub?output=csv'
df = pd.read_csv(file_url, header=None)
df.columns = ['edible', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']

# %%
ml_df = df.copy()
cor_df = df.copy()
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   edible                    8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
# Loop over object columns and return a count of  unique values
cor_df['stalk-root'].replace('?', np.NaN, inplace=True)
dtypes = cor_df.dtypes
str_cols = dtypes[dtypes=='object'].index

for col in str_cols:
  print(f'Column: {col}')
  print(cor_df[col].value_counts())
  print('\n\n')
# Out:
# Column: edible
# e    4208
# p    3916
# Name: edible, dtype: int64
#
#
#
# Column: cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
#
#
#
# Column: cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
#
#
#
# Column: cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: cap-color, dtype: int64
#
#
#
# Column: bruises
# f    4748
# t    3376
# Name: bruises, dtype: int64
#
#
#
# Column: odor
# n    3528
# f    2160
# y     576
# s     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
#
#
#
# Column: gill-attachment
# f    7914
# a     210
# Name: gill-attachment, dtype: int64
#
#
#
# Column: gill-spacing
# c    6812
# w    1312
# Name: gill-spacing, dtype: int64
#
#
#
# Column: gill-size
# b    5612
# n    2512
# Name: gill-size, dtype: int64
#
#
#
# Column: gill-color
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# Name: gill-color, dtype: int64
#
#
#
# Column: stalk-shape
# t    4608
# e    3516
# Name: stalk-shape, dtype: int64
#
#
#
# Column: stalk-root
# b    3776
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64
#
#
#
# Column: stalk-surface-above-ring
# s    5176
# k    2372
# f     552
# y      24
# Name: stalk-surface-above-ring, dtype: int64
#
#
#
# Column: stalk-surface-below-ring
# s    4936
# k    2304
# f     600
# y     284
# Name: stalk-surface-below-ring, dtype: int64
#
#
#
# Column: stalk-color-above-ring
# w    4464
# p    1872
# g     576
# n     448
# b     432
# o     192
# e      96
# c      36
# y       8
# Name: stalk-color-above-ring, dtype: int64
#
#
#
# Column: stalk-color-below-ring
# w    4384
# p    1872
# g     576
# n     512
# b     432
# o     192
# e      96
# c      36
# y      24
# Name: stalk-color-below-ring, dtype: int64
#
#
#
# Column: veil-type
# p    8124
# Name: veil-type, dtype: int64
#
#
#
# Column: veil-color
# w    7924
# n      96
# o      96
# y       8
# Name: veil-color, dtype: int64
#
#
#
# Column: ring-number
# o    7488
# t     600
# n      36
# Name: ring-number, dtype: int64
#
#
#
# Column: ring-type
# p    3968
# e    2776
# l    1296
# f      48
# n      36
# Name: ring-type, dtype: int64
#
#
#
# Column: spore-print-color
# w    2388
# n    1968
# k    1872
# h    1632
# r      72
# u      48
# o      48
# y      48
# b      48
# Name: spore-print-color, dtype: int64
#
#
#
# Column: population
# v    4040
# y    1712
# s    1248
# n     400
# a     384
# c     340
# Name: population, dtype: int64
#
#
#
# Column: habitat
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: habitat, dtype: int64

# %%
ohe = OneHotEncoder(sparse=False, handle_unknown='ignore').fit(cor_df)
cor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   edible                    8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                5644 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
corr = ml_df.corr()
print(corr)
# sns.heatmap(corr, cmap='YlGnBu', annot=True);
# Out:
# Empty DataFrame
# Columns: []
# Index: []
